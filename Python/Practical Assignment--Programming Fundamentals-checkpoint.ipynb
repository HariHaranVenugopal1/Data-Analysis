# %%
##Programming Fundamentals (COSC2531) Assignment 1
##Student name: Hariharan Venugopal
## Student ID: s3905219
## parts completed:PART A and PART B
## Requirement not met : part C

def print_menu():
    print("**************************************************")
    print("Please choose from the following options")
    print("1) Order a meal")
    print("2) Add/Update dishes and prices")
    print("3) Display existing customers details")
    print("4) Display existing dishes information")
    print("5) Exit the program")
    print("**************************************************")

while True:
    print_menu()
    choice = int(input("Please make a choice "))
    Myfood = {"Pizza":20,"Burgers":15,"Sandwiches":10}
    
    if choice ==1:
        while True:
            myOrder = 0
            name1 = input("Please enter your name ")
            mobile_number = int(input("Please enter your mobile number "))
            print("Welcome to Hotel Hidden Leaf", name1)
            print("1. Pizza  20$\n2. Burgers  15$\n3. Sandwiches  10$")
            option = (input('Enter your choice: ')) 
            if option == "Pizza":
                print('Hot Pizza', pizza)
                Myfood = pizza
                break
            elif option == "Burgers":
                print('Hamburgers', burgers)
                Myfood = burgers
                break
            elif option == "Sandwiches":
                print('Sandwiches',Sandwiches)
                Myfood = Sandwiches
                break
            else:
                print('Invalid option. Try Again')
        myOrder = option
        while True:
            quantity = int(input("Enter the number of dishes "))
            if quantity > 0:
                Order_cost = quantity * Myfood
                break
            else:
                print("Please be positive")
        while True:
            rewards_program = input("Do you have rewards program ")
            if rewards_program =="Yes":
                service_tax = 0
                break
            elif rewards_program =="No":
                service_tax=Order_cost*0.20
                break
            else:
                print("Please type the correct plan")
        total_amount = Order_cost + service_tax
        print("**********************************************************")
        print("Receipt of Customer", name1)
        print("Mobile Number of the customer", mobile_number)
        print("**********************************************************")
        print("Dishes","\t\t","Quantity","\t","Food")
        print(myOrder,"\t\t",quantity,"\t\t", Myfood)
        print("Servicefees:                   ",service_tax)
        print("Total cost:                    ",total_amount)
    
    elif choice ==2:
        n = int(input("Enter the number of food added"))
        for i in range(n):
            food = input("Enter food name: ")
            price = input("Enter food price: ")
            Myfood[food] = price
        print(Myfood)

    elif choice == 3:
        print("Your name is ", name1)
        print("Your mobile number is ", mobile_number)
        print("Do you have reward program", rewards_program)
    
    elif choice == 4:
        print("The cost of the pizza are", pizza)
        print("the cost od the burgers are", burgers)
        print("The cost of the Sandwiches are", Sandwiches)
        print("Your choice is", option)
        
    elif choice == 5:
        print("Thanks for ordering")
        break
